# %% [markdown]
# <a href="https://colab.research.google.com/github/realBagher/Iran_family_income_analysis-_g6/blob/main/Hypothesis/Hypothesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hypothesis

# %% [markdown]
# ## Income Test

# %%
! git clone https://github.com/realBagher/Iran_family_income_analysis-_g6
# Out:
# Cloning into 'Iran_family_income_analysis-_g6'...
# remote: Enumerating objects: 476, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 476 (delta 21), reused 62 (delta 12), pack-reused 390
# Receiving objects: 100% (476/476), 82.54 MiB | 16.99 MiB/s, done.
# Resolving deltas: 100% (126/126), done.
# Updating files: 100% (221/221), done.

# %%
! pip install PyGWalker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 956.2/956.2 kB 43.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.0/381.0 kB 39.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 88.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlglot
#     Found existing installation: sqlglot 20.11.0
#     Uninstalling sqlglot-20.11.0:
#       Successfully uninstalled sqlglot-20.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.8.0 requires sqlglot<=20.11,>=20.8.0, but you have sqlglot 25.0.3 which is incompatible.
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pygwalker as pyg
import seaborn as sns
import scipy as sp

# %%
R1398P4S01 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1398/R1398P4S01.csv')
R1398P4S02 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1398/R1398P4S02.csv')
R1398P4S03 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1398/R1398P4S03.csv')
R1398P4S04 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1398/R1398P4S04.csv')

R1399P4S01 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1399/R1399P4S01.csv')
R1399P4S02 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1399/R1399P4S02.csv')
R1399P4S03 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1399/R1399P4S03.csv')
R1399P4S04 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1399/R1399P4S04.csv')

R1400P4S01 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1400/R1400P4S01.csv')
R1400P4S02 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1400/R1400P4S02.csv')
R1400P4S03 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1400/R1400P4S03.csv')
R1400P4S04 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1400/R1400P4S04.csv')

R1401P4S01 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1401/R1401P4S01.csv')
R1401P4S02 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1401/R1401P4S02.csv')
R1401P4S03 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1401/R1401P4S03.csv')
R1401P4S04 = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1401/R1401P4S04.csv')

# %%
U1398P4S01 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1398/U1398P4S01.csv')
U1398P4S02 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1398/U1398P4S02.csv')
U1398P4S03 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1398/U1398P4S03.csv')
U1398P4S04 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1398/U1398P4S04.csv')

U1399P4S01 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1399/U1399P4S01.csv')
U1399P4S02 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1399/U1399P4S02.csv')
U1399P4S03 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1399/U1399P4S03.csv')
U1399P4S04 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1399/U1399P4S04.csv')

U1400P4S01 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1400/U1400P4S01.csv')
U1400P4S02 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1400/U1400P4S02.csv')
U1400P4S03 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1400/U1400P4S03.csv')
U1400P4S04 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1400/U1400P4S04.csv')

U1401P4S01 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1401/U1401P4S01.csv')
U1401P4S02 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1401/U1401P4S02.csv')
U1401P4S03 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1401/U1401P4S03.csv')
U1401P4S04 = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1401/U1401P4S04.csv')

# %% [markdown]
# ### R Total Income for each Year

# %%
R1398P4S01
R1398P4S01_g = R1398P4S01.groupby('Address').agg({'netincome_w_y': 'sum'})
R1399P4S01_g = R1399P4S01.groupby('Address').agg({'netincome_w_y': 'sum'})
R1400P4S01_g = R1400P4S01.groupby('Address').agg({'netincome_w_y': 'sum'})
R1401P4S01_g = R1401P4S01.groupby('Address').agg({'netincome_w_y': 'sum'})

R1398_99P4S01_g = pd.merge(R1398P4S01_g, R1399P4S01_g, how='outer', on='Address', suffixes=['_98', '_99'])
R1400_01P4S01_g = pd.merge(R1400P4S01_g, R1401P4S01_g, how='outer', on='Address', suffixes=['_1400', '_1401'])

R_P4S01_g = pd.merge(R1398_99P4S01_g, R1400_01P4S01_g, how='outer', on='Address')

#plt.hist(R1401P4S01_g.netincome_w_y, bins=30)

# %%
R1398P4S02
#R1398P4S02.Address.sort_values()
R1398P4S02_g = R1398P4S02.groupby('Address').agg({'income_s_y': 'sum'})
R1399P4S02_g = R1399P4S02.groupby('Address').agg({'income_s_y': 'sum'})
R1400P4S02_g = R1400P4S02.groupby('Address').agg({'income_s_y': 'sum'})
R1401P4S02_g = R1401P4S02.groupby('Address').agg({'income_s_y': 'sum'})

# %%
R1398P4S03
#R1398P4S03.Address.sort_values()
R1398P4S03_g = R1398P4S03.groupby('Address').agg({'Total_income': 'sum'})
R1399P4S03_g = R1399P4S03.groupby('Address').agg({'Total_income': 'sum'})
R1400P4S03_g = R1400P4S03.groupby('Address').agg({'Total_income': 'sum'})
R1401P4S03_g = R1401P4S03.groupby('Address').agg({'Total_income': 'sum'})

# %%
R1398P4S04
#R1398P4S04.info()
#R1398P4S04.Address.sort_values()
R1398P4S04_g = R1398P4S04.groupby('Address').agg({'subsidy': 'sum'})
R1399P4S04_g = R1399P4S04.groupby('Address').agg({'subsidy': 'sum'})
R1400P4S04_g = R1400P4S04.groupby('Address').agg({'subsidy': 'sum'})
R1401P4S04_g = R1401P4S04.groupby('Address').agg({'subsidy': 'sum'})

# %%
#pyg.walk(R1398P4S03)

# %%
R1398P4S01_02_g = pd.merge(R1398P4S01_g, R1398P4S02_g, how='outer', on='Address')
R1398P4S03_04_g = pd.merge(R1398P4S03_g, R1398P4S04_g, how='outer', on='Address')
R1398P4_g = pd.merge(R1398P4S01_02_g, R1398P4S03_04_g, how='outer', on='Address')
R1398P4_g.fillna(0, inplace=True)
R1398P4_g['total_in'] = R1398P4_g['netincome_w_y'] + R1398P4_g['income_s_y'] + R1398P4_g['Total_income'] + R1398P4_g['subsidy']
R1398P4_total = R1398P4_g.drop(['netincome_w_y', 'income_s_y', 'Total_income', 'subsidy'], axis=1)
R1398P4_total.sort_values('total_in')
plt.hist(R1398P4_total, bins=200)
plt.show()

# %%
R1399P4S01_02_g = pd.merge(R1399P4S01_g, R1399P4S02_g, how='outer', on='Address')
R1399P4S03_04_g = pd.merge(R1399P4S03_g, R1399P4S04_g, how='outer', on='Address')
R1399P4_g = pd.merge(R1399P4S01_02_g, R1399P4S03_04_g, how='outer', on='Address')
R1399P4_g.fillna(0, inplace=True)
R1399P4_g['total_in'] = R1399P4_g['netincome_w_y'] + R1399P4_g['income_s_y'] + R1399P4_g['Total_income'] + R1399P4_g['subsidy']
R1399P4_total = R1399P4_g.drop(['netincome_w_y', 'income_s_y', 'Total_income', 'subsidy'], axis=1)
R1399P4_total.sort_values('total_in')
plt.hist(R1399P4_total, bins=200)
plt.show()

# %%
R1400P4S01_02_g = pd.merge(R1400P4S01_g, R1400P4S02_g, how='outer', on='Address')
R1400P4S03_04_g = pd.merge(R1400P4S03_g, R1400P4S04_g, how='outer', on='Address')
R1400P4_g = pd.merge(R1400P4S01_02_g, R1400P4S03_04_g, how='outer', on='Address')
R1400P4_g.fillna(0, inplace=True)
R1400P4_g['total_in'] = R1400P4_g['netincome_w_y'] + R1400P4_g['income_s_y'] + R1400P4_g['Total_income'] + R1400P4_g['subsidy']
R1400P4_total = R1400P4_g.drop(['netincome_w_y', 'income_s_y', 'Total_income', 'subsidy'], axis=1)
R1400P4_total.sort_values('total_in')
plt.hist(R1400P4_total, bins=200)
plt.show()

# %%
R1401P4S01_02_g = pd.merge(R1401P4S01_g, R1401P4S02_g, how='outer', on='Address')
R1401P4S03_04_g = pd.merge(R1401P4S03_g, R1401P4S04_g, how='outer', on='Address')
R1401P4_g = pd.merge(R1401P4S01_02_g, R1401P4S03_04_g, how='outer', on='Address')
R1401P4_g.fillna(0, inplace=True)
R1401P4_g['total_in'] = R1401P4_g['netincome_w_y'] + R1401P4_g['income_s_y'] + R1401P4_g['Total_income'] + R1401P4_g['subsidy']
R1401P4_total = R1401P4_g.drop(['netincome_w_y', 'income_s_y', 'Total_income', 'subsidy'], axis=1)
R1401P4_total.sort_values('total_in')
plt.hist(R1401P4_total, bins=200)
plt.show()

# %% [markdown]
# ### U Total Income for each Year

# %%
U1398P4S01_g = U1398P4S01.groupby('Address').agg({'netincome_w_y': 'sum'})
U1399P4S01_g = U1399P4S01.groupby('Address').agg({'netincome_w_y': 'sum'})
U1400P4S01_g = U1400P4S01.groupby('Address').agg({'netincome_w_y': 'sum'})
U1401P4S01_g = U1401P4S01.groupby('Address').agg({'netincome_w_y': 'sum'})

# %%
U1398P4S02_g = U1398P4S02.groupby('Address').agg({'income_s_y': 'sum'})
U1399P4S02_g = U1399P4S02.groupby('Address').agg({'income_s_y': 'sum'})
U1400P4S02_g = U1400P4S02.groupby('Address').agg({'income_s_y': 'sum'})
U1401P4S02_g = U1401P4S02.groupby('Address').agg({'income_s_y': 'sum'})

# %%
U1398P4S03_g = U1398P4S03.groupby('Address').agg({'Total_income': 'sum'})
U1399P4S03_g = U1399P4S03.groupby('Address').agg({'Total_income': 'sum'})
U1400P4S03_g = U1400P4S03.groupby('Address').agg({'Total_income': 'sum'})
U1401P4S03_g = U1401P4S03.groupby('Address').agg({'Total_income': 'sum'})

# %%
U1398P4S04_g = U1398P4S04.groupby('Address').agg({'subsidy': 'sum'})
U1399P4S04_g = U1399P4S04.groupby('Address').agg({'subsidy': 'sum'})
U1400P4S04_g = U1400P4S04.groupby('Address').agg({'subsidy': 'sum'})
U1401P4S04_g = U1401P4S04.groupby('Address').agg({'subsidy': 'sum'})

# %%
U1398P4S01_02_g = pd.merge(U1398P4S01_g, U1398P4S02_g, how='outer', on='Address')
U1398P4S03_04_g = pd.merge(U1398P4S03_g, U1398P4S04_g, how='outer', on='Address')
U1398P4_g = pd.merge(U1398P4S01_02_g, U1398P4S03_04_g, how='outer', on='Address')
U1398P4_g.fillna(0, inplace=True)
U1398P4_g['total_in'] = U1398P4_g['netincome_w_y'] + U1398P4_g['income_s_y'] + U1398P4_g['Total_income'] + U1398P4_g['subsidy']
U1398P4_total = U1398P4_g.drop(['netincome_w_y', 'income_s_y', 'Total_income', 'subsidy'], axis=1)
U1398P4_total.sort_values('total_in')
plt.hist(U1398P4_total, bins=300)
plt.show()

# %%
U1399P4S01_02_g = pd.merge(U1399P4S01_g, U1399P4S02_g, how='outer', on='Address')
U1399P4S03_04_g = pd.merge(U1399P4S03_g, U1399P4S04_g, how='outer', on='Address')
U1399P4_g = pd.merge(U1399P4S01_02_g, U1399P4S03_04_g, how='outer', on='Address')
U1399P4_g.fillna(0, inplace=True)
U1399P4_g['total_in'] = U1399P4_g['netincome_w_y'] + U1399P4_g['income_s_y'] + U1399P4_g['Total_income'] + U1399P4_g['subsidy']
U1399P4_total = U1399P4_g.drop(['netincome_w_y', 'income_s_y', 'Total_income', 'subsidy'], axis=1)
U1399P4_total.sort_values('total_in')
plt.hist(U1399P4_total, bins=300)
plt.show()

# %%
U1400P4S01_02_g = pd.merge(U1400P4S01_g, U1400P4S02_g, how='outer', on='Address')
U1400P4S03_04_g = pd.merge(U1400P4S03_g, U1400P4S04_g, how='outer', on='Address')
U1400P4_g = pd.merge(U1400P4S01_02_g, U1400P4S03_04_g, how='outer', on='Address')
U1400P4_g.fillna(0, inplace=True)
U1400P4_g['total_in'] = U1400P4_g['netincome_w_y'] + U1400P4_g['income_s_y'] + U1400P4_g['Total_income'] + U1400P4_g['subsidy']
U1400P4_total = U1400P4_g.drop(['netincome_w_y', 'income_s_y', 'Total_income', 'subsidy'], axis=1)
U1400P4_total.sort_values('total_in')
plt.hist(U1400P4_total, bins=300)
plt.show()

# %%
U1401P4S01_02_g = pd.merge(U1401P4S01_g, U1401P4S02_g, how='outer', on='Address')
U1401P4S03_04_g = pd.merge(U1401P4S03_g, U1401P4S04_g, how='outer', on='Address')
U1401P4_g = pd.merge(U1401P4S01_02_g, U1401P4S03_04_g, how='outer', on='Address')
U1401P4_g.fillna(0, inplace=True)
U1401P4_g['total_in'] = U1401P4_g['netincome_w_y'] + U1401P4_g['income_s_y'] + U1401P4_g['Total_income'] + U1401P4_g['subsidy']
U1401P4_total = U1401P4_g.drop(['netincome_w_y', 'income_s_y', 'Total_income', 'subsidy'], axis=1)
U1401P4_total.sort_values('total_in')
plt.hist(U1401P4_total, bins=300)
plt.show()

# %% [markdown]
# ### R Total Income for each Year - چهارمحال بختیاری

# %%
R1398Data = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1398/R1398Data.csv')
R1399Data = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1399/R1399Data.csv')
R1400Data = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1400/R1400Data.csv')
R1401Data = pd.read_csv('/content/Iran_family_income_analysis-_g6/R1401/R1401Data.csv')

# %%
R1398P4_total_Data = pd.merge(R1398P4_total, R1398Data, how='inner', on='Address')
R1398P4_total_ChB = R1398P4_total_Data[R1398P4_total_Data.province == 5]
#print(R1398P4_total_ChB)
R1398P4_total_ChB_final = R1398P4_total_ChB.drop(['province', 'town'], axis=1)
R1398P4_total_ChB_final = R1398P4_total_ChB_final.set_index('Address')

kwargs = dict(alpha=0.3, kde=True, bins=30)
sns.histplot(R1398P4_total_ChB_final, **kwargs)
# Out:
# <Axes: ylabel='Count'>

# %%
R1399P4_total_Data = pd.merge(R1399P4_total, R1399Data, how='inner', on='Address')
R1399P4_total_ChB = R1399P4_total_Data[R1399P4_total_Data.province == 5]
#print(R1399P4_total_ChB)
R1399P4_total_ChB_final = R1399P4_total_ChB.drop(['province', 'town'], axis=1)
R1399P4_total_ChB_final = R1399P4_total_ChB_final.set_index('Address')

kwargs = dict(alpha=0.3, kde=True, bins=30)
sns.histplot(R1399P4_total_ChB_final, **kwargs)
# Out:
# <Axes: ylabel='Count'>

# %%
R1400P4_total_Data = pd.merge(R1400P4_total, R1400Data, how='inner', on='Address')
R1400P4_total_ChB = R1400P4_total_Data[R1400P4_total_Data.province == 5]
#print(R1400P4_total_ChB)
R1400P4_total_ChB_final = R1400P4_total_ChB.drop(['province', 'town'], axis=1)
R1400P4_total_ChB_final = R1400P4_total_ChB_final.set_index('Address')

kwargs = dict(alpha=0.3, kde=True, bins=30)
sns.histplot(R1400P4_total_ChB_final, **kwargs)
# Out:
# <Axes: ylabel='Count'>

# %%
R1401P4_total_Data = pd.merge(R1401P4_total, R1401Data, how='inner', on='Address')
R1401P4_total_ChB = R1401P4_total_Data[R1401P4_total_Data.province == 5]
#print(R1401P4_total_ChB)
R1401P4_total_ChB_final = R1401P4_total_ChB.drop(['province', 'town'], axis=1)
R1401P4_total_ChB_final = R1401P4_total_ChB_final.set_index('Address')

kwargs = dict(alpha=0.3, kde=True, bins=30)
sns.histplot(R1401P4_total_ChB_final, **kwargs)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### U Total Income for each Year - چهارمحال بختیاری

# %%
U1398Data = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1398/U1398Data.csv')
U1399Data = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1399/U1399Data.csv')
U1400Data = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1400/U1400Data.csv')
U1401Data = pd.read_csv('/content/Iran_family_income_analysis-_g6/U1401/U1401Data.csv')

# %%
U1398P4_total_Data = pd.merge(U1398P4_total, U1398Data, how='inner', on='Address')
U1398P4_total_ChB = U1398P4_total_Data[U1398P4_total_Data.province == 5]
#print(U1398P4_total_ChB)
U1398P4_total_ChB_final = U1398P4_total_ChB.drop(['province', 'town'], axis=1)
U1398P4_total_ChB_final = U1398P4_total_ChB_final.set_index('Address')

kwargs = dict(alpha=0.3, kde=True, bins=30)
sns.histplot(U1398P4_total_ChB_final, **kwargs)
# Out:
# <Axes: ylabel='Count'>

# %%
U1399P4_total_Data = pd.merge(U1399P4_total, U1399Data, how='inner', on='Address')
U1399P4_total_ChB = U1399P4_total_Data[U1399P4_total_Data.province == 5]
#print(U1399P4_total_ChB)
U1399P4_total_ChB_final = U1399P4_total_ChB.drop(['province', 'town'], axis=1)
U1399P4_total_ChB_final = U1399P4_total_ChB_final.set_index('Address')

kwargs = dict(alpha=0.3, kde=True, bins=30)
sns.histplot(U1399P4_total_ChB_final, **kwargs)
# Out:
# <Axes: ylabel='Count'>

# %%
U1400P4_total_Data = pd.merge(U1400P4_total, U1400Data, how='inner', on='Address')
U1400P4_total_ChB = U1400P4_total_Data[U1400P4_total_Data.province == 5]
#print(U1400P4_total_ChB)
U1400P4_total_ChB_final = U1400P4_total_ChB.drop(['province', 'town'], axis=1)
U1400P4_total_ChB_final = U1400P4_total_ChB_final.set_index('Address')

kwargs = dict(alpha=0.3, kde=True, bins=30)
sns.histplot(U1400P4_total_ChB_final, **kwargs)
# Out:
# <Axes: ylabel='Count'>

# %%
U1401P4_total_Data = pd.merge(U1401P4_total, U1401Data, how='inner', on='Address')
U1401P4_total_ChB = U1401P4_total_Data[U1401P4_total_Data.province == 5]
#print(U1401P4_total_ChB)
U1401P4_total_ChB_final = U1401P4_total_ChB.drop(['province', 'town'], axis=1)
U1401P4_total_ChB_final = U1401P4_total_ChB_final.set_index('Address')

kwargs = dict(alpha=0.3, kde=True, bins=30)
sns.histplot(U1401P4_total_ChB_final, **kwargs)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### Income Test 1398

# %%
R1398P4_total_ChB_final
U1398P4_total_ChB_final
# Out:
#                 total_in
# Address
# 11401171708  303760000.0
# 11401171711  594960018.0
# 11401171714  294995009.0
# 11401171720  296380000.0
# 11401171723  291620000.0
# ...                  ...
# 11409183223  455700000.0
# 11409183323   49440000.0
# 11409183414  266490000.0
# 11409183420   92420000.0
# 11409183514  269470000.0
#
# [648 rows x 1 columns]

# %%
sns.kdeplot(R1398P4_total_ChB_final.total_in, label='R1398', fill=True)
sns.kdeplot(U1398P4_total_ChB_final.total_in, label='U1398', fill=True)


plt.legend()
plt.show()

# %% [markdown]
# **Shapiro normality results:**

# %%
R1398_test_stat, R1398_p_value = sp.stats.shapiro(R1398P4_total_ChB_final.total_in)
R1398_p_value
# Out:
# 3.109826096441911e-19

# %%
U1398_test_stat, U1398_p_value = sp.stats.shapiro(U1398P4_total_ChB_final.total_in)
U1398_p_value
# Out:
# 2.7788886287478516e-31

# %% [markdown]
# **D'Agostino normality results:**

# %%
R1398_dagostino_test_stat, R1398_dagostino_p_value = sp.stats.normaltest(R1398P4_total_ChB_final.total_in)
R1398_dagostino_p_value
# Out:
# 2.528503748782319e-37

# %%
U1398_dagostino_test_stat, U1398_dagostino_p_value = sp.stats.normaltest(U1398P4_total_ChB_final.total_in)
U1398_dagostino_p_value
# Out:
# 5.677683756416084e-137

# %% [markdown]
# **U-test**

# %%
u_statistic, p_value = sp.stats.mannwhitneyu(R1398P4_total_ChB_final.total_in, U1398P4_total_ChB_final.total_in)
p_value
# Out:
# 5.883213452487551e-17

# %% [markdown]
# H0 Rejected
#
# درآمدهای خانوارهای شهری و روستایی در استان چهارمحال بختیاری در سال ۹۸ باهم برابر نیست

# %% [markdown]
# ### Income Test 1399

# %%
R1399P4_total_ChB_final
U1399P4_total_ChB_final
# Out:
#                 total_in
# Address
# 11401171714  421390000.0
# 11401171720  388380000.0
# 11401171729  746730000.0
# 11401171814  298915000.0
# 11401171820  131140000.0
# ...                  ...
# 11409183223  452460000.0
# 11409183226   59580000.0
# 11409183324  142710000.0
# 11409183414  329920000.0
# 11409183420  145860000.0
#
# [636 rows x 1 columns]

# %%
sns.kdeplot(R1399P4_total_ChB_final.total_in, label='R1399', fill=True)
sns.kdeplot(U1399P4_total_ChB_final.total_in, label='U1399', fill=True)


plt.legend()
plt.show()

# %% [markdown]
# **Shapiro normality results:**

# %%
R1399_test_stat, R1399_p_value = sp.stats.shapiro(R1399P4_total_ChB_final.total_in)
R1399_p_value
# Out:
# 2.477323135755706e-22

# %%
U1399_test_stat, U1399_p_value = sp.stats.shapiro(U1399P4_total_ChB_final.total_in)
U1399_p_value
# Out:
# 1.6926294355981784e-22

# %% [markdown]
# **D'Agostino normality results:**

# %%
R1399_dagostino_test_stat, R1399_dagostino_p_value = sp.stats.normaltest(R1399P4_total_ChB_final.total_in)
R1399_dagostino_p_value
# Out:
# 1.7805466382274594e-73

# %%
U1399_dagostino_test_stat, U1399_dagostino_p_value = sp.stats.normaltest(U1399P4_total_ChB_final.total_in)
U1399_dagostino_p_value
# Out:
# 4.698129345380178e-50

# %% [markdown]
# **U-test**

# %%
u_statistic, p_value = sp.stats.mannwhitneyu(R1399P4_total_ChB_final.total_in, U1399P4_total_ChB_final.total_in)
p_value
# Out:
# 6.934803787250026e-11

# %% [markdown]
# H0 Rejected
#
# درآمدهای خانوارهای شهری و روستایی در استان چهارمحال بختیاری در سال ۹۹ باهم برابر نیست

# %% [markdown]
# ### Income Test 1400

# %%
R1400P4_total_ChB_final
U1400P4_total_ChB_final
# Out:
#                  total_in
# Address
# 11401171723  6.837400e+08
# 11401171729  9.226400e+08
# 11401171820  2.542800e+08
# 11401171826  1.309190e+09
# 11401171920  8.284060e+08
# ...                   ...
# 11409183223  4.357600e+08
# 11409183324  1.725800e+08
# 11409183420  1.690800e+08
# 11409183426  3.751800e+08
# 11409183532  5.660800e+08
#
# [651 rows x 1 columns]

# %%
sns.kdeplot(R1400P4_total_ChB_final.total_in, label='R1400', fill=True)
sns.kdeplot(U1400P4_total_ChB_final.total_in, label='U1400', fill=True)


plt.legend()
plt.show()

# %% [markdown]
# **Shapiro normality results:**

# %%
R1400_test_stat, R1400_p_value = sp.stats.shapiro(R1400P4_total_ChB_final.total_in)
R1400_p_value
# Out:
# 1.3801175179383157e-23

# %%
U1400_test_stat, U1400_p_value = sp.stats.shapiro(U1400P4_total_ChB_final.total_in)
U1400_p_value
# Out:
# 2.37297830771117e-29

# %% [markdown]
# **D'Agostino normality results:**

# %%
R1400_dagostino_test_stat, R1400_dagostino_p_value = sp.stats.normaltest(R1400P4_total_ChB_final.total_in)
R1400_dagostino_p_value
# Out:
# 1.7473922626463114e-70

# %%
U1400_dagostino_test_stat, U1400_dagostino_p_value = sp.stats.normaltest(U1400P4_total_ChB_final.total_in)
U1400_dagostino_p_value
# Out:
# 1.3116100854366007e-124

# %% [markdown]
# **U-test**

# %%
u_statistic, p_value = sp.stats.mannwhitneyu(R1400P4_total_ChB_final.total_in, U1400P4_total_ChB_final.total_in)
p_value
# Out:
# 1.8454659027508173e-12

# %% [markdown]
# H0 Rejected
#
# درآمدهای خانوارهای شهری و روستایی در استان چهارمحال بختیاری در سال ۱۴۰۰ باهم برابر نیست

# %% [markdown]
# ### Income Test 1401

# %%
R1401P4_total_ChB_final
U1401P4_total_ChB_final
# Out:
#                  total_in
# Address
# 11401171729  1.364395e+09
# 11401171738  2.067545e+09
# 11401171741  1.310525e+09
# 11401171826  1.799010e+09
# 11401171829  4.557800e+08
# ...                   ...
# 11409183135  1.349300e+08
# 11409183141  5.727900e+08
# 11409183426  4.903500e+08
# 11409183532  9.601850e+08
# 11409183541  1.038145e+09
#
# [657 rows x 1 columns]

# %%
sns.kdeplot(R1401P4_total_ChB_final.total_in, label='R1401', fill=True)
sns.kdeplot(U1401P4_total_ChB_final.total_in, label='U1401', fill=True)


plt.legend()
plt.show()

# %% [markdown]
# **Shapiro normality results:**

# %%
R1401_test_stat, R1401_p_value = sp.stats.shapiro(R1401P4_total_ChB_final.total_in)
R1401_p_value
# Out:
# 2.8560258880074454e-20

# %%
U1401_test_stat, U1401_p_value = sp.stats.shapiro(U1401P4_total_ChB_final.total_in)
U1401_p_value
# Out:
# 8.506701993481895e-21

# %% [markdown]
# **D'Agostino normality results:**

# %%
R1401_dagostino_test_stat, R1401_dagostino_p_value = sp.stats.normaltest(R1401P4_total_ChB_final.total_in)
R1401_dagostino_p_value
# Out:
# 3.490577473000356e-45

# %%
U1401_dagostino_test_stat, U1401_dagostino_p_value = sp.stats.normaltest(U1401P4_total_ChB_final.total_in)
U1401_dagostino_p_value
# Out:
# 1.2958571797037887e-52

# %% [markdown]
# **U-test**

# %%
u_statistic, p_value = sp.stats.mannwhitneyu(R1401P4_total_ChB_final.total_in, U1401P4_total_ChB_final.total_in)
p_value
# Out:
# 1.569753669831523e-11

# %% [markdown]
# H0 Rejected
#
# درآمدهای خانوارهای شهری و روستایی در استان چهارمحال بختیاری در سال ۱۴۰۱ باهم برابر نیست

# %% [markdown]
# ### Income Test all years

# %%
sns.kdeplot(R1398P4_total_ChB_final.total_in, label='R1398', fill=True)
sns.kdeplot(U1398P4_total_ChB_final.total_in, label='U1398', fill=True)

sns.kdeplot(R1399P4_total_ChB_final.total_in, label='R1399', fill=True)
sns.kdeplot(U1399P4_total_ChB_final.total_in, label='U1399', fill=True)

sns.kdeplot(R1400P4_total_ChB_final.total_in, label='R1400', fill=True)
sns.kdeplot(U1400P4_total_ChB_final.total_in, label='U1400', fill=True)

sns.kdeplot(R1401P4_total_ChB_final.total_in, label='R1401', fill=True)
sns.kdeplot(U1401P4_total_ChB_final.total_in, label='U1401', fill=True)


plt.legend()
plt.show()
